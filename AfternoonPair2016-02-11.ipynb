# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('hospital-costs.csv', delimiter=',')

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383493 entries, 0 to 383492
# Data columns (total 14 columns):
# Year                                   383493 non-null int64
# Facility Id                            383493 non-null int64
# Facility Name                          383493 non-null object
# APR DRG Code                           383493 non-null int64
# APR Severity of Illness Code           383493 non-null int64
# APR DRG Description                    383493 non-null object
# APR Severity of Illness Description    383329 non-null object
# APR Medical Surgical Code              383329 non-null object
# APR Medical Surgical Description       383493 non-null object
# Discharges                             383493 non-null int64
# Mean Charge                            383493 non-null float64
# Median Charge                          383493 non-null float64
# Mean Cost                              383493 non-null float64
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383493 entries, 0 to 383492
# Data columns (total 14 columns):
# Year                                   383493 non-null int64
# Facility Id                            383493 non-null int64
# Facility Name                          383493 non-null object
# APR DRG Code                           383493 non-null int64
# APR Severity of Illness Code           383493 non-null int64
# APR DRG Description                    383493 non-null object
# APR Severity of Illness Description    383329 non-null object
# APR Medical Surgical Code              383329 non-null object
# APR Medical Surgical Description       383493 non-null object
# Discharges                             383493 non-null int64
# Mean Charge                            383493 non-null float64
# Median Charge                          383493 non-null float64
# Mean Cost                              383493 non-null float64
# ...

# %%
file1.describe().T
# Out:
#                                count          mean           std   min    25%  \
# Year                          383493   2009.992096      0.816167  2009   2009
# Facility Id                   383493    931.197406    633.379977     1    511
# APR DRG Code                  383493    375.874013    246.981328     1    192
# APR Severity of Illness Code  383493      2.338846      1.042050     0      1
# Discharges                    383493     20.514742     79.758116     1      2
# Mean Charge                   383493  40574.359767  65910.535627     8  11809
# Median Charge                 383493  37185.949282  62610.587963     8  10625
# Mean Cost                     383493  16834.624948  29527.505553     2   4995
# Median Cost                   383493  15279.536244  27828.357605     2   4457
#
#                                 50%    75%      max
# Year                           2010   2011     2011
# Facility Id                     889   1306     9250
# ...

# %%
file1['APR DRG Description']
# Out:
# 0         Tracheostomy W MV 96+ Hours W Extensive Proced...
# 1         Tracheostomy W MV 96+ Hours W/O Extensive Proc...
# 2                          Extracranial Vascular Procedures
# 3                 Other Nervous System & Related Procedures
# 4                                 Nervous System Malignancy
# 5                                 Nervous System Malignancy
# 6         Degenerative Nervous System Disorders Exc Mult...
# 7         Degenerative Nervous System Disorders Exc Mult...
# 8         Degenerative Nervous System Disorders Exc Mult...
# 9         Multiple Sclerosis & Other Demyelinating Diseases
# 10        Multiple Sclerosis & Other Demyelinating Diseases
# 11                                  Intracranial Hemorrhage
# 12                                  Intracranial Hemorrhage
# 13                    CVA & Precerebral Occlusion W Infarct
# 14                    CVA & Precerebral Occlusion W Infarct
# 15                    CVA & Precerebral Occlusion W Infarct
# ...

# %%
file1.query('APR DRG Description == Meningitis')
# Out:
#   File "<unknown>", line 1
#     APR DRG Description ==Meningitis
#           ^
# SyntaxError: invalid syntax

# %%
#df[df['A'].str.contains("hello")]
#menin = file1[file1['APR DRG Description'].str.contains('Viral Meningitis')]
#menin = file1.loc['APR DRG Description'] = 'Viral Meningitis'
menin = file1[file1['APR DRG Description'] == 'Viral Meningitis']
menin.head(5)
# Out:
#      Year  Facility Id                                Facility Name  \
# 24   2011          324  Adirondack Medical Center-Saranac Lake Site
# 557  2011            1               Albany Medical Center Hospital
# 558  2011            1               Albany Medical Center Hospital
# 559  2011            1               Albany Medical Center Hospital
# 560  2011            1               Albany Medical Center Hospital
#
#      APR DRG Code  APR Severity of Illness Code APR DRG Description  \
# 24             51                             1    Viral Meningitis
# 557            51                             1    Viral Meningitis
# 558            51                             2    Viral Meningitis
# 559            51                             3    Viral Meningitis
# 560            51                             4    Viral Meningitis
#
#     APR Severity of Illness Description APR Medical Surgical Code  \
# 24                                Minor                         M
# ...

# %%
menin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1074 entries, 24 to 383108
# Data columns (total 14 columns):
# Year                                   1074 non-null int64
# Facility Id                            1074 non-null int64
# Facility Name                          1074 non-null object
# APR DRG Code                           1074 non-null int64
# APR Severity of Illness Code           1074 non-null int64
# APR DRG Description                    1074 non-null object
# APR Severity of Illness Description    1074 non-null object
# APR Medical Surgical Code              1074 non-null object
# APR Medical Surgical Description       1074 non-null object
# Discharges                             1074 non-null int64
# Mean Charge                            1074 non-null float64
# Median Charge                          1074 non-null float64
# Mean Cost                              1074 non-null float64
# Median Cost                            1074 non-null float64
# ...

# %%
menin['total_charges'] = menin['Discharges'] * menin['Mean Charge']
# Out:
# /Users/johnnysand/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
menin
# Out:
#         Year  Facility Id                                   Facility Name  \
# 24      2011          324     Adirondack Medical Center-Saranac Lake Site
# 557     2011            1                  Albany Medical Center Hospital
# 558     2011            1                  Albany Medical Center Hospital
# 559     2011            1                  Albany Medical Center Hospital
# 560     2011            1                  Albany Medical Center Hospital
# 1635    2011            4                        Albany Memorial Hospital
# 1636    2011            4                        Albany Memorial Hospital
# 1637    2011            4                        Albany Memorial Hospital
# 2199    2011          325                       Alice Hyde Medical Center
# 2200    2011          325                       Alice Hyde Medical Center
# 2201    2011          325                       Alice Hyde Medical Center
# 2680    2011          116                      Arnot Ogden Medical Center
# ...

# %%
menin['total_cost'] = menin['Discharges'] * menin['Mean Cost']
# Out:
# /Users/johnnysand/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
menin.head(5)
menin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1074 entries, 24 to 383108
# Data columns (total 16 columns):
# Year                                   1074 non-null int64
# Facility Id                            1074 non-null int64
# Facility Name                          1074 non-null object
# APR DRG Code                           1074 non-null int64
# APR Severity of Illness Code           1074 non-null int64
# APR DRG Description                    1074 non-null object
# APR Severity of Illness Description    1074 non-null object
# APR Medical Surgical Code              1074 non-null object
# APR Medical Surgical Description       1074 non-null object
# Discharges                             1074 non-null int64
# Mean Charge                            1074 non-null float64
# Median Charge                          1074 non-null float64
# Mean Cost                              1074 non-null float64
# Median Cost                            1074 non-null float64
# ...

# %%
menin['markup'] = 100 * (menin['total_charges'] / menin['total_cost'])
# Out:
# /Users/johnnysand/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
menin.head(5)
# Out:
#      Year  Facility Id                                Facility Name  \
# 24   2011          324  Adirondack Medical Center-Saranac Lake Site
# 557  2011            1               Albany Medical Center Hospital
# 558  2011            1               Albany Medical Center Hospital
# 559  2011            1               Albany Medical Center Hospital
# 560  2011            1               Albany Medical Center Hospital
#
#      APR DRG Code  APR Severity of Illness Code APR DRG Description  \
# 24             51                             1    Viral Meningitis
# 557            51                             1    Viral Meningitis
# 558            51                             2    Viral Meningitis
# 559            51                             3    Viral Meningitis
# 560            51                             4    Viral Meningitis
#
#     APR Severity of Illness Description APR Medical Surgical Code  \
# 24                                Minor                         M
# ...

# %%
menin['markup'].min()
# Out:
# 75.734488596753309

# %%
menin[menin['markup'] == menin['markup'].max()]
# Out:
#         Year  Facility Id        Facility Name  APR DRG Code  \
# 298842  2009         1450  Lenox Hill Hospital            51
#
#         APR Severity of Illness Code APR DRG Description  \
# 298842                             1    Viral Meningitis
#
#        APR Severity of Illness Description APR Medical Surgical Code  \
# 298842                               Minor                         M
#
#        APR Medical Surgical Description  Discharges  Mean Charge  \
# 298842                          Medical           2        31389
#
#         Median Charge  Mean Cost  Median Cost  total_charges  total_cost  \
# 298842          31389       3397         3397          62778        6794
#
#             markup
# 298842  924.021195

# %%
menin[menin['markup'] == menin['markup'].min()]
# Out:
#         Year  Facility Id                    Facility Name  APR DRG Code  \
# 373822  2009         1320  University Hospital of Brooklyn            51
#
#         APR Severity of Illness Code APR DRG Description  \
# 373822                             2    Viral Meningitis
#
#        APR Severity of Illness Description APR Medical Surgical Code  \
# 373822                            Moderate                         M
#
#        APR Medical Surgical Description  Discharges  Mean Charge  \
# 373822                          Medical           2        15209
#
#         Median Charge  Mean Cost  Median Cost  total_charges  total_cost  \
# 373822          15209      20082        20082          30418       40164
#
#            markup
# 373822  75.734489

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383493 entries, 0 to 383492
# Data columns (total 14 columns):
# Year                                   383493 non-null int64
# Facility Id                            383493 non-null int64
# Facility Name                          383493 non-null object
# APR DRG Code                           383493 non-null int64
# APR Severity of Illness Code           383493 non-null int64
# APR DRG Description                    383493 non-null object
# APR Severity of Illness Description    383329 non-null object
# APR Medical Surgical Code              383329 non-null object
# APR Medical Surgical Description       383493 non-null object
# Discharges                             383493 non-null int64
# Mean Charge                            383493 non-null float64
# Median Charge                          383493 non-null float64
# Mean Cost                              383493 non-null float64
# ...

# %%
prob2 = file1.groupby(by=['APR DRG Description'])['Discharges'].sum()

# %%
prob2.sort_values(ascending=False).head(10)
# Out:
# APR DRG Description
# Neonate Birthwt >2499G, Normal Newborn Or Neonate W Other Problem    632412
# Vaginal Delivery                                                     458034
# Cesarean Delivery                                                    245265
# Heart Failure                                                        173826
# Other Pneumonia                                                      162344
# Septicemia & Disseminated Infections                                 161739
# Chronic Obstructive Pulmonary Disease                                146461
# Cellulitis & Other Bacterial Skin Infections                         124617
# Cardiac Arrhythmia & Conduction Disorders                            121042
# Chest Pain                                                           117630
# Name: Discharges, dtype: int64

# %%
prob3 = menin[['Facility Name', 'total_charges', 'total_cost']]

# %%
prob3.head(10)
# Out:
#                                     Facility Name  total_charges  total_cost
# 24    Adirondack Medical Center-Saranac Lake Site          17116        7006
# 557                Albany Medical Center Hospital         251028       86811
# 558                Albany Medical Center Hospital         233167       78441
# 559                Albany Medical Center Hospital         168444       44970
# 560                Albany Medical Center Hospital         130600       39086
# 1635                     Albany Memorial Hospital          23082        8253
# 1636                     Albany Memorial Hospital          17038        6306
# 1637                     Albany Memorial Hospital          14004        5052
# 2199                    Alice Hyde Medical Center          19304        8588
# 2200                    Alice Hyde Medical Center          15811        6941

# %%
prob3['Net Income'] = prob3['total_charges'] - prob3['total_cost']
# Out:
# /Users/johnnysand/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
#prob3.head(10)
totalincome = prob3.groupby(by=['Facility Name'])[['total_charges', 'total_cost', 'Net Income']].sum()

# %%
#menin[menin['markup'] == menin['markup'].max()]
totalincome.sort_values('Net Income', ascending=False).head(1)
# Out:
#                                  total_charges  total_cost  Net Income
# Facility Name
# North Shore University Hospital        5076331     1129349     3946982

# %%
totalincome.sort_values('Net Income', ascending=True).head(1)
# Out:
#                                    total_charges  total_cost  Net Income
# Facility Name
# Wyoming County Community Hospital           7350        5973        1377

# %%
menin2 = menin[['Facility Name', 'APR DRG Description', 'APR Severity of Illness Description', 'Discharges', 'Mean Charge', 'Median Charge', 'Mean Cost']]

# %%
menin2.head(10)
practice = menin[[0, 1, 4]]

# %%
practice.head(10)
# Out:
#       Year  Facility Id  APR Severity of Illness Code
# 24    2011          324                             1
# 557   2011            1                             1
# 558   2011            1                             2
# 559   2011            1                             3
# 560   2011            1                             4
# 1635  2011            4                             1
# 1636  2011            4                             2
# 1637  2011            4                             3
# 2199  2011          325                             1
# 2200  2011          325                             2

# %%
menin2.head(10)
# Out:
#                                     Facility Name APR DRG Description  \
# 24    Adirondack Medical Center-Saranac Lake Site    Viral Meningitis
# 557                Albany Medical Center Hospital    Viral Meningitis
# 558                Albany Medical Center Hospital    Viral Meningitis
# 559                Albany Medical Center Hospital    Viral Meningitis
# 560                Albany Medical Center Hospital    Viral Meningitis
# 1635                     Albany Memorial Hospital    Viral Meningitis
# 1636                     Albany Memorial Hospital    Viral Meningitis
# 1637                     Albany Memorial Hospital    Viral Meningitis
# 2199                    Alice Hyde Medical Center    Viral Meningitis
# 2200                    Alice Hyde Medical Center    Viral Meningitis
#
#      APR Severity of Illness Description  Discharges  Mean Charge  \
# 24                                 Minor           1        17116
# ...

# %%
#df[(df['Age'] > 30) & (df['Donation'] > 10000)] # subselect
modmen = menin2[menin2['APR Severity of Illness Description'] == 'Moderate']

# %%
modmen['Mean Cost'].min()
modmen[modmen['Mean Cost'] == modmen['Mean Cost'].max()]
# Out:
#                  Facility Name APR DRG Description  \
# 48363  Lutheran Medical Center    Viral Meningitis
#
#       APR Severity of Illness Description  Discharges  Mean Charge  \
# 48363                            Moderate           2        71850
#
#        Median Charge  Mean Cost
# 48363          71850      50605

# %%
modmen[modmen['Mean Cost'] == modmen['Mean Cost'].min()]
# Out:
#                                Facility Name APR DRG Description  \
# 258259  Aurelia Osborn Fox Memorial Hospital    Viral Meningitis
#
#        APR Severity of Illness Description  Discharges  Mean Charge  \
# 258259                            Moderate           1         1179
#
#         Median Charge  Mean Cost
# 258259           1179       1040

# %%
modmen.head(10)
# Out:
#                                  Facility Name APR DRG Description  \
# 558             Albany Medical Center Hospital    Viral Meningitis
# 1636                  Albany Memorial Hospital    Viral Meningitis
# 2200                 Alice Hyde Medical Center    Viral Meningitis
# 2681                Arnot Ogden Medical Center    Viral Meningitis
# 3462                 Auburn Community Hospital    Viral Meningitis
# 3970      Aurelia Osborn Fox Memorial Hospital    Viral Meningitis
# 4491                  Bellevue Hospital Center    Viral Meningitis
# 6065      Beth Israel Med Center-Kings Hwy Div    Viral Meningitis
# 6753  Beth Israel Medical Center/Petrie Campus    Viral Meningitis
# 7770            Bon Secours Community Hospital    Viral Meningitis
#
#      APR Severity of Illness Description  Discharges  Mean Charge  \
# 558                             Moderate          11        21197
# 1636                            Moderate           1        17038
# ...

# %%
#frame['HighScore'] = frame[['test1','test2','test3']].max(axis=1)
modmen2 = modmen[(modmen['Discharges'] > 3)]
modmen2[modmen2['Mean Cost'] == modmen2['Mean Cost'].max()]
# Out:
#                                             Facility Name APR DRG Description  \
# 234825  St Lukes Roosevelt Hospital - St Lukes Hospita...    Viral Meningitis
#
#        APR Severity of Illness Description  Discharges  Mean Charge  \
# 234825                            Moderate           4        79245
#
#         Median Charge  Mean Cost
# 234825          48006      24743

# %%
modmen2[modmen2['Mean Cost'] == modmen2['Mean Cost'].min()]
# Out:
#                             Facility Name APR DRG Description  \
# 55958  Millard Fillmore Suburban Hospital    Viral Meningitis
#
#       APR Severity of Illness Description  Discharges  Mean Charge  \
# 55958                            Moderate           6         6614
#
#        Median Charge  Mean Cost
# 55958           6784       2649

# %%
file1.head(1)

# %%
mostdis = file1[[2, 5, 6, 9, 10]]

# %%
mostdis.head(10)
# Out:
#                                  Facility Name  \
# 0  Adirondack Medical Center-Saranac Lake Site
# 1  Adirondack Medical Center-Saranac Lake Site
# 2  Adirondack Medical Center-Saranac Lake Site
# 3  Adirondack Medical Center-Saranac Lake Site
# 4  Adirondack Medical Center-Saranac Lake Site
# 5  Adirondack Medical Center-Saranac Lake Site
# 6  Adirondack Medical Center-Saranac Lake Site
# 7  Adirondack Medical Center-Saranac Lake Site
# 8  Adirondack Medical Center-Saranac Lake Site
# 9  Adirondack Medical Center-Saranac Lake Site
#
#                                  APR DRG Description  \
# 0  Tracheostomy W MV 96+ Hours W Extensive Proced...
# 1  Tracheostomy W MV 96+ Hours W/O Extensive Proc...
# 2                   Extracranial Vascular Procedures
# 3          Other Nervous System & Related Procedures
# 4                          Nervous System Malignancy
# 5                          Nervous System Malignancy
# 6  Degenerative Nervous System Disorders Exc Mult...
# ...

# %%
#df.groupby(['col5', 'col2']).size()
grouped = mostdis.groupby(['APR DRG Description', 'APR Severity of Illness Description'])
#grouped = mostdis.groupby(['APR Severity of Illness Description', 'APR DRG Description'])

# %%
for group in grouped:
    print grouped['Discharges'].max()
# Out:
# APR DRG Description                                                    APR Severity of Illness Description
# Abdominal Pain                                                         Extreme                                   8
#                                                                        Major                                    69
#                                                                        Minor                                   127
#                                                                        Moderate                                158
# Acute & Subacute Endocarditis                                          Extreme                                  14
#                                                                        Major                                    13
#                                                                        Minor                                     3
# ...

# %%
df2[df2['Discharges']==df2['Discharges'].max()]
# Out:
#                                                                                         Discharges  \
# APR DRG Description                                APR Severity of Illness Description
# Neonate Birthwt >2499G, Normal Newborn Or Neona... Minor                                    528921
#
#                                                                                         Mean Charge
# APR DRG Description                                APR Severity of Illness Description
# Neonate Birthwt >2499G, Normal Newborn Or Neona... Minor                                    1452569

# %%
df2[df2['Discharges']==df2['Discharges'].min()]
# Out:
#                                                                                 Discharges  \
# APR DRG Description                        APR Severity of Illness Description
# Craniotomy For Multiple Significant Trauma Minor                                         1
# Neonate Bwt <1500G W Major Procedure       Minor                                         1
# Neonate W Ecmo                             Moderate                                      1
#
#                                                                                 Mean Charge
# APR DRG Description                        APR Severity of Illness Description
# Craniotomy For Multiple Significant Trauma Minor                                      75585
# Neonate Bwt <1500G W Major Procedure       Minor                                      83134
# Neonate W Ecmo                             Moderate                                 1116663
